# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh21-design/Image-Media_Generation/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORT LIBRARIES

# %%
# !pip install pytesseract pillow opencv-python google-generativeai
# !apt-get install -y tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %% [markdown]
# OCR CODE

# %%
import cv2
import pytesseract
from PIL import Image
from google.colab import files

# Upload image
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# Read image
img = cv2.imread(img_path)

# OCR extraction
ocr_text = pytesseract.image_to_string(img)
print("🔍 OCR Extracted Text:\n", ocr_text)
# Out:
#      <input type="file" id="files-d53f6ed6-53b9-4ed0-96b0-4c600a429e5d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d53f6ed6-53b9-4ed0-96b0-4c600a429e5d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# LLM REFINE CODE

# %%
import google.generativeai as genai

genai.configure(api_key="YOUR_GEMINI_API_KEY")
model = genai.GenerativeModel("gemini-2.5-pro")

prompt = f"""
The following text was extracted from an image using OCR: {ocr_text}.
Please clean it, correct errors, add topic name and present it in readable English.
"""

response = model.generate_content(prompt)

print("*******Cleaned Extracted Text******\n", response.text)
# Out:
# *******Cleaned Extracted Text******
#  Of course. Here is the cleaned and corrected text, presented in a clear and readable format.
#
# ***
#
# ### **Topic: A Comparison of the Scientific and Mathematical Methods**
#
# The text outlines the parallel, yet distinct, processes used in science and mathematics to build knowledge.
#
# **Science**
# 1.  Make observations.
# 2.  Collect data and look for patterns.
# 3.  State hypotheses.
# 4.  Construct a theory.
# 5.  Gain a better understanding of **our** universe.
#
# **Math**
# 1.  Make assumptions.
# 2.  Collect data and look for patterns.
# 3.  State conjectures.
# 4.  Prove theorems.
# 5.  Gain a better understanding of **a** universe.
