# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh21-design/Image-Media_Generation/blob/main/Task_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 10.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
blog_text = """
Meet the all-new Gametop, a laptop designed for those who demand more from their gaming experience.

Gametop is not just another device; it is the ultimate gaming laptop,
built to elevate every session and redefine what is possible.

Under the hood, Gametop is powered by the latest Intel Core i9 processor,
delivering lightning-fast speeds and seamless multitasking.

Paired with cutting-edge RTX graphics,
this laptop handles the most demanding games with ease.

Advanced cooling technology ensures optimal performance,
even during marathon gaming sessions.

Level up your game with customizable RGB lighting,
a responsive mechanical keyboard,
and high-fidelity audio.

Gametop’s ultra-fast refresh rate and minimal input lag provide a competitive edge,
while its long-lasting battery keeps you in the action, wherever you are.

Step into the future of gaming with Gametop —
the laptop that empowers you to play harder, faster, and smarter.

Elevate your game.
Choose Gametop.
"""

# %%
# Convert to speech
tts = gTTS(text=blog_text, lang='en', slow=False)

# save audio
tts.save("blog_audio.mp3")

# play audio
Audio("blog_audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
